# %%
import pandas as pd

# %%
df = pd.read_csv('movies.csv')
df.columns = ['id','title','year','genres','directors','cast','rating','votes']
# Out:
# C:\Users\s.dulguun\AppData\Local\Temp\ipykernel_29284\3046438102.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('movies.csv')

# %%
df
# Out:
#                id                        title  year  \
# 0       tt0000009                   Miss Jerry  1894
# 1       tt0000502                     Bohemios  1905
# 2       tt0000574  The Story of the Kelly Gang  1906
# 3       tt0000591             The Prodigal Son  1907
# 4       tt0000615           Robbery Under Arms  1907
# ...           ...                          ...   ...
# 321940  tt9916428          The Secret of China  2019
# 321941  tt9916460                    Pink Taxi  2019
# 321942  tt9916538          Kuambil Lagi Hatiku  2019
# 321943  tt9916706              Dankyavar Danka  2013
# 321944  tt9916730                       6 Gunn  2017
#
#                             genres   directors  \
# 0                          Romance   nm0085156
# 1                               \N   nm0063413
# 2       Action,Adventure,Biography   nm0846879
# 3                            Drama   nm0141150
# 4                            Drama   nm0533958
# ...

# %%
df
# Out:
#                id                        title  year  \
# 0       tt0000009                   Miss Jerry  1894
# 1       tt0000502                     Bohemios  1905
# 2       tt0000574  The Story of the Kelly Gang  1906
# 3       tt0000591             The Prodigal Son  1907
# 4       tt0000615           Robbery Under Arms  1907
# ...           ...                          ...   ...
# 321940  tt9916428          The Secret of China  2019
# 321941  tt9916460                    Pink Taxi  2019
# 321942  tt9916538          Kuambil Lagi Hatiku  2019
# 321943  tt9916706              Dankyavar Danka  2013
# 321944  tt9916730                       6 Gunn  2017
#
#                             genres   directors  \
# 0                          Romance   nm0085156
# 1                               \N   nm0063413
# 2       Action,Adventure,Biography   nm0846879
# 3                            Drama   nm0141150
# 4                            Drama   nm0533958
# ...

# %%
df[df['title']]
